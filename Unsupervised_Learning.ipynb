# %%
# Unsupervised Learning
# What is Unsupervised Learning?
# Unsupervised learning is a type of machine learning where the model is trained on unlabeled data. 
# The goal is to find hidden patterns or intrinsic structures in the input data. 
# Unlike supervised learning where the model is trained on labeled data, unsupervised learning 
# does not have predefined output labels.

# Real-world applications of unsupervised learning include 
# clustering, anomaly detection, and dimensionality reduction.
'''
- Customer Segmentation: Grouping customers based on purchasing behavior.
- Anomaly Detection: Identifying unusual patterns in data, such as fraud detection.
- Dimensionality Reduction: Reducing the number of features in a dataset while preserving 
important information, often used for data visualization.
-Recommendation Systems: Suggesting products or content to users based on their preferences and behavior.
-Image and Video Analysis: Grouping similar images or videos together for organization or retrieval.
-Document Clustering: Organizing large collections of documents into meaningful clusters for easier 
navigation and search.
-Medical Diagnosis: Identifying patterns in medical data to assist in diagnosis and treatment planning.
-Social Network Analysis: Understanding relationships and communities within social networks.
-Market Basket Analysis: Discovering associations between products purchased together by customers.
-Genetic Data Analysis: Identifying patterns in genetic data for research and personalized medicine.
-Network Security: Detecting unusual network traffic patterns that may indicate security threats.

'''


# Example Customer Segmentation using K-Means Clustering
# A supermarket wants to segment its customers based on their purchasing behavior.
# Customer, Age, Monthly Income, Spending Score
# 

# Fraud Detection using Isolation Forest
# Transaction ID, Transaction Amount, Transaction Time, Location
# Normal transactions are clustered together, while fraudulent transactions are isolated as anomalies.
# Kampala to Jinja, will cost you 8000 -15000
# 

# Suspicious transaction happens 
# Kampala to Jinja 
# Payment of 1,500,000

#

# %%
# Example 2: Image Clustering Using K-Means (Unsupervised Learning)

# Image Clustering Using K-Means
# What is Clustering
# What is K-Means

# %%
# Import Libraries 
import numpy as np
